# %% [markdown]
# Question 1: Generate a business day range for July 2017 (July 1 to July 31) using USFederalHolidayCalendar.
#
# Question 2: Set the date range generated in Q1 as the index of aapl_no_dates.csv. First check the number of rows in the CSV and compare it with the number of generated dates (ensuring they match).
#
# Question 3: Create a custom holiday calendar that includes your birthday as a holiday. Use this custom calendar to generate a date range for April 2017.
#
# Question 4: Generate a date range for July 2017 using CustomBusinessDay with weekmask='Sun Mon Tue Wed Thu' so that Friday and Saturday are skipped.
#
# Question 5: Add July 4, 2017, as an extra holiday to the CustomBusinessDay weekmask setup from Q4 and regenerate the range. Verify that July 4 is skipped in the output.
#
# Question 6: What is the difference between using standard business frequency (freq='B') versus USFederalHolidayCalendar()? Generate both ranges for July 2017 and compare them to identify which specific dates differ.

# %%
import pandas as pd
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
df = pd.read_csv("../datasets/aapl_no_dates.csv")
usb = CustomBusinessDay(calendar=USFederalHolidayCalendar())
rng = pd.date_range(start="07/01/2017",end="07/21/2017",freq=usb)
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-10  144.11  145.95  143.37  145.06  21090636
# 2017-07-11  144.73  145.85  144.38  145.53  19781836
# 2017-07-12  145.87  146.18  144.82  145.74  24884478
# 2017-07-13  145.50  148.49  145.44  147.77  25199373
# 2017-07-14  147.97  149.33  147.33  149.04  20132061
# 2017-07-17  148.82  150.90  148.57  149.56  23793456
# 2017-07-18  149.20  150.13  148.67  150.08  17868792
# 2017-07-19  150.48  151.42  149.95  151.02  20922969
# 2017-07-20  151.50  151.74  150.19  150.34  17243748
# 2017-07-21  149.99  150.44  148.88  150.27  26252630

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=11, day=27),#, observance=nearest_workday),
    ]
    
my_bday = CustomBusinessDay(calendar=myCalendar())
pd.date_range('11/1/2017','11/30/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-11-01', '2017-11-02', '2017-11-03', '2017-11-06',
#                '2017-11-07', '2017-11-08', '2017-11-09', '2017-11-10',
#                '2017-11-13', '2017-11-14', '2017-11-15', '2017-11-16',
#                '2017-11-17', '2017-11-20', '2017-11-21', '2017-11-22',
#                '2017-11-23', '2017-11-24', '2017-11-28', '2017-11-29',
#                '2017-11-30'],
#               dtype='datetime64[ns]', freq='C')

# %%
b = CustomBusinessDay(weekmask= 'Mon Tue Wed Thu Sun')
rng2 = pd.date_range(start="7/1/2017",end="7/31/2017",freq=b)
rng2
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-16', '2017-07-17',
#                '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27',
#                '2017-07-30', '2017-07-31'],
#               dtype='datetime64[ns]', freq='C')

# %%
b = CustomBusinessDay(weekmask= 'Mon Tue Wed Thu Sun',holidays=["2017-07-04"])

# %%
rng2 = pd.date_range(start="7/1/2017",end="7/31/2017",freq=b)
rng2
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-09', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-16', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-23', '2017-07-24',
#                '2017-07-25', '2017-07-26', '2017-07-27', '2017-07-30',
#                '2017-07-31'],
#               dtype='datetime64[ns]', freq='C')
