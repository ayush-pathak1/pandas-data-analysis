# %% [markdown]
# Q1: pd.Period("2025") banao — uska start_time aur end_time print karo.
#
# Q2: Monthly period banao "2025-06" — m+2 karo (2 mahine aage).
#
# Q3: "2025Q2" quarterly period banao — q+1 karo aur batao kaunsa quarter aaya.
#
# Q4: pd.period_range('2020', '2023', freq='Q-JAN') se range banao, phir ek random Series banao us index se (np.random.randn).
#
# Q5: Q4 wale Series se '2021' ka data nikalo (partial indexing).
#
# Q6: Q4 wale Series ko to_timestamp() se DatetimeIndex mein convert karo, phir wapas to_period() se PeriodIndex mein.
#
# Q7: wmt.csv load karo, Line Item ko index banao, transpose karo (.T), phir pd.PeriodIndex se index ko quarterly period mein convert karo.
#
# Q8: Q7 ke DataFrame mein start_date column add karo (index.map(lambda x: x.start_time) se).
#
# Q9: pd.Period("2025Q1", freq='Q-JAN') ka asfreq('M', how='end') karo — kaunsa month aaya?
#
# Q10: Q4 wale period_range mein se idx[0] ka start_time aur end_time print karo.

# %%
import pandas as pd
y = pd.Period("2025")
y.start_time

# %%
y.end_time

# %%
m = pd.Period("2025-06")
m+2

# %%
q = pd.Period("2025Q2")
q+1

# %%
import numpy as np
idx = pd.period_range('2020', '2023', freq='Q-JAN')
ps = pd.Series(np.random.randn(len(idx)), idx)
ps

# %%
ps['2021']

# %%
pst = ps.to_timestamp()
pst

# %% [markdown]
# Q7: wmt.csv load karo, Line Item ko index banao, transpose karo (.T), phir pd.PeriodIndex se index ko quarterly period mein convert karo.
#
# Q8: Q7 ke DataFrame mein start_date column add karo (index.map(lambda x: x.start_time) se).
#
# Q9: pd.Period("2025Q1", freq='Q-JAN') ka asfreq('M', how='end') karo — kaunsa month aaya?
#
# Q10: Q4 wale period_range mein se idx[0] ka start_time aur end_time print karo.
