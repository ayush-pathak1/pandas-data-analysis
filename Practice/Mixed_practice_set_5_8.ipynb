# %%
import pandas as pd
df = pd.read_csv("../datasets/nyc_weather.csv")
df['EST'] = pd.to_datetime(df['EST'])
df = df.set_index('EST')
new = df.select_dtypes(include='number').interpolate(method="time")
new
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
# 2016-01-06           33         4        35                 30.50
# 2016-01-07           39        11        33                 30.28
# 2016-01-08           39        29        64                 30.20
# 2016-01-09           44        38        77                 30.16
# 2016-01-10           50        46        71                 29.59
# 2016-01-11           33         8        37                 29.92
# 2016-01-12           35        15        53                 29.85
# 2016-01-13           26         4        42                 29.94
# ...

# %%
df2 = pd.DataFrame({
    'Rating': ['Excellent','Good','Poor']
})
new_df = df2.replace(['Excellent','Good','Poor'],[100,70,30])
new_df
# Out:
# C:\Users\ap504\AppData\Local\Temp\ipykernel_22064\3251091005.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df = df2.replace(['Excellent','Good','Poor'],[100,70,30])
#    Rating
# 0     100
# 1      70
# 2      30

# %%
new_df = df.groupby('Events')['Temperature'].mean()
new_df
# Out:
# Events
# Fog-Snow    31.000000
# Rain        45.500000
# Snow        26.333333
# Name: Temperature, dtype: float64
